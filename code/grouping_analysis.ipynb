# %%
import duckdb as dd
import pandas as pd

# %%
df = dd.sql("SELECT * FROM 'page_groups_0015.parquet'").df()

# %%
df
# Out:
#                                                  title  group
# 0                             UK_Album_Downloads_Chart      0
# 1        Lists_of_UK_Album_Downloads_Chart_number_ones      0
# 2                                      UK_Albums_Chart      0
# 3                                           Ed_Sheeran      0
# 4        Whatever_People_Say_I_Am,_That's_What_I'm_Not      0
# ...                                                ...    ...
# 3390771      UEFA_Women's_Euro_2017_qualifying_Group_4      0
# 3390772        2021_UEFA_Women's_Under-19_Championship      0
# 3390773                     2003_UEFA–CAF_Meridian_Cup      0
# 3390774                                      UFO_Yepha  19403
# 3390775                                 UFO_(musician)  19403
#
# [3390776 rows x 2 columns]
